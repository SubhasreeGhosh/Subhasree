# %%
import pandas as pd

# %%
data = pd.read_csv('data\\data\\global_superstore\\global_superstore_2016.csv',encoding=('ISO-8859-1'))

# %%
data
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 0       40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# ...       ...                       ...         ...         ...
# 51285   29002   IN-2015-KE1642066-42174   6/19/2015   6/19/2015
# 51286   34337  US-2014-ZD21925140-41765  05-06-2014  05-10-2014
# 51287   31315  CA-2012-ZD21925140-41147   8/26/2012   8/31/2012
# 51288    9596   MX-2013-RB1979518-41322   2/17/2013   2/21/2013
# 51289    6147   MX-2013-MC1810093-41416   5/22/2013   5/26/2013
#
#             Ship Mode   Customer ID       Customer Name      Segment  \
# 0         First Class  AB-100151402       Aaron Bergman     Consumer
# ...

# %%
data.shape
# Out:
# (51290, 24)

# %%
data.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
#checking the types of the columns
data.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Postal Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales              object
# Quantity            int64
# Discount          float64
# Profit             object
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
data[["Order Date","Ship Date"]] = data[["Order Date","Ship Date"]].apply(pd.to_datetime)

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                     object
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
#removing the "$" sign from sales column and converting it into float

# %%
data['Sales'] = data['Sales'].str.strip("$")

# %%
data['Sales']
# Out:
# 0          221.98
# 1        3,709.40
# 2        5,175.17
# 3        2,892.51
# 4        2,832.96
#            ...
# 51285       65.10
# 51286       16.72
# 51287        8.56
# 51288       13.44
# 51289       61.38
# Name: Sales, Length: 51290, dtype: object

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                     object
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
data['Sales']
# Out:
# 0          221.98
# 1        3,709.40
# 2        5,175.17
# 3        2,892.51
# 4        2,832.96
#            ...
# 51285       65.10
# 51286       16.72
# 51287        8.56
# 51288       13.44
# 51289       61.38
# Name: Sales, Length: 51290, dtype: object

# %%
data['Sales'] = data['Sales'].str.replace(',', '')

# %%
data['Sales']
# Out:
# 0         221.98
# 1        3709.40
# 2        5175.17
# 3        2892.51
# 4        2832.96
#            ...
# 51285      65.10
# 51286      16.72
# 51287       8.56
# 51288      13.44
# 51289      61.38
# Name: Sales, Length: 51290, dtype: object

# %%
data['Sales'] = data['Sales'].astype(float)

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
#removing the "(""$" sign from sales column and converting it into float
data['Profit'] = data['Profit'].str.strip("(")
data['Profit'] = data['Profit'].str.strip("$")
data['Profit'] = data['Profit'].str.strip(")")

# %%
data['Profit']
# Out:
# 0         62.15
# 1         288.77
# 2        919.97
# 3          96.54
# 4        311.52
#           ...
# 51285      4.50
# 51286      3.34
# 51287      2.48
# 51288      2.40
# 51289      1.80
# Name: Profit, Length: 51290, dtype: object

# %%
data['Profit'] = data['Profit'].str.replace(',', '')

# %%
data['Profit']
# Out:
# 0         62.15
# 1         288.77
# 2        919.97
# 3          96.54
# 4        311.52
#           ...
# 51285      4.50
# 51286      3.34
# 51287      2.48
# 51288      2.40
# 51289      1.80
# Name: Profit, Length: 51290, dtype: object

# %%
data['Profit'] = data['Profit'].astype(float)

# %%
data['Profit']
# Out:
# 0         62.15
# 1        288.77
# 2        919.97
# 3         96.54
# 4        311.52
#           ...
# 51285      4.50
# 51286      3.34
# 51287      2.48
# 51288      2.40
# 51289      1.80
# Name: Profit, Length: 51290, dtype: float64

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
data.drop(['Row ID', 'Order Date','Ship Date','Ship Mode'], axis = 1)
# Out:
#                        Order ID   Customer ID       Customer Name  \
# 0      CA-2014-AB10015140-41954  AB-100151402       Aaron Bergman
# 1        IN-2014-JR162107-41675     JR-162107       Justin Ritter
# 2        IN-2014-CR127307-41929     CR-127307        Craig Reiter
# 3       ES-2014-KM1637548-41667    KM-1637548    Katherine Murray
# 4       SG-2014-RH9495111-41948    RH-9495111         Rick Hansen
# ...                         ...           ...                 ...
# 51285   IN-2015-KE1642066-42174    KE-1642066     Katrina Edelman
# 51286  US-2014-ZD21925140-41765  ZD-219251408  Zuschuss Donatelli
# 51287  CA-2012-ZD21925140-41147  ZD-219251404  Zuschuss Donatelli
# 51288   MX-2013-RB1979518-41322    RB-1979518          Ross Baird
# 51289   MX-2013-MC1810093-41416    MC-1810093       Mick Crebagga
#
#            Segment  Postal Code           City            State  \
# 0         Consumer      73120.0  Oklahoma City         Oklahoma
# ...

# %%
#1.Total, how many orders have cross the shipping cost of 500?

# %%
data.loc[data['Shipping Cost'] > 500 , 'Order ID'].count()
# Out:
# 120

# %%
#2.Count the number of segments, countries, regions, markets, categories, and sub-categories present in the global_superstore_2016 data.

# %%
data[["Segment","Country","Region","Market","Category","Sub-Category"]].count()
# Out:
# Segment         51290
# Country         51290
# Region          51290
# Market          51290
# Category        51290
# Sub-Category    51290
# dtype: int64

# %%
#3.Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500.

# %%
data.loc[(data['Country']=='India') & (data['Category']< 'Technology') & (data['Shipping Cost']>500),['Order ID']]
# Out:
#                    Order ID
# 29  IN-2013-BP1123058-41329
# 42  IN-2015-VG2180558-42273
# 57  IN-2013-GP1474058-41419
# 67  IN-2015-CS1184558-42354
# 79  IN-2012-RM1937558-41209

# %%
#4.Get the list of Order ID's where the Indian customer's have bought the things under the category 'Technology' the Sales greater than 500.

# %%
data.loc[(data['Country']=='India') & (data['Category']== 'Technology') & (data['Sales']>500),['Order ID']]
# Out:
#                       Order ID
# 41     IN-2015-BF1100558-42319
# 48     IN-2015-SW2027558-42125
# 55     IN-2013-SG2047058-41424
# 90     IN-2013-GP1474058-41419
# 130    IN-2014-SV2081558-41968
# ...                        ...
# 14874  IN-2013-ML1826558-41503
# 15236  IN-2015-HG1484558-42339
# 23250  IN-2013-MA1799558-41565
# 24316  IN-2012-DP1316558-41173
# 35903  IN-2013-JS1568558-41371
#
# [163 rows x 1 columns]

# %%
#5.How many people from the State 'Karnataka' have bought the things under the category 'Technology'?

# %%
data.loc[(data['State'] == 'Karnataka') & (data['Category']=='Technology')  , 'Customer ID'].count()
# Out:
# 21

# %%
#6.Get the list of countries where the 'Profit' and 'Shipping Cost's are greater than or equal to 2000 and 300 respectively.

# %%
data.loc[(data['Profit']>2000) & (data['Shipping Cost']>300),['Country','Profit','Shipping Cost']]
# Out:
#               Country   Profit  Shipping Cost
# 17              Italy  3979.08         778.32
# 42              India  2097.03         658.35
# 81            Morocco  2597.28         568.45
# 109       Netherlands  2211.17         520.89
# 192    United Kingdom  2071.44         432.13
# 215             Japan  2939.31         413.80
# 245         Lithuania  2750.28         390.09
# 313             India  2817.99         353.85
# 334         Australia  2316.51         346.60
# 362          Pakistan  3009.44         333.10
# 419     United States  4946.37         498.70
# 2257    United States  2504.22         567.95
# 6422    United States  2365.98         516.91
# 11123   United States  3177.48         581.12
# 11755   United States  6599.98         451.63
# 23110   United States  3839.99         674.82
# 24214   United States  2302.97         350.09
# 25238   United States  5039.99         363.19
# 31453   United States  2400.97         466.33
# ...

# %%
data.loc[(data["Country"]=="India") & (data["Category"]=="Technology"),['State']]
# Out:
#                 State
# 41            Haryana
# 48          Jharkhand
# 55     Madhya Pradesh
# 90              Delhi
# 130           Gujarat
# ...               ...
# 39631          Kerala
# 40262          Punjab
# 42345           Bihar
# 43976       Telangana
# 51172      Tamil Nadu
#
# [354 rows x 1 columns]

# %%
#9 for Profit

# %%
y1 = data.groupby(['Category','Sub-Category'],as_index=True).Profit.max()

# %%
y1
# Out:
# Category         Sub-Category
# Furniture        Bookcases       2316.51
#                  Chairs          2211.17
#                  Furnishings      561.96
#                  Tables          2750.28
# Office Supplies  Appliances      3979.08
#                  Art              371.23
#                  Binders         4946.37
#                  Envelopes        279.36
#                  Fasteners        127.26
#                  Labels           385.38
#                  Paper            352.30
#                  Storage          802.17
#                  Supplies        1049.34
# Technology       Accessories     1345.50
#                  Copiers         8399.98
#                  Machines        6599.98
#                  Phones          4088.38
# Name: Profit, dtype: float64

# %%
y2 = data.groupby(['Category','Sub-Category'],as_index=True).Profit.min()

# %%
y2
# Out:
# Category         Sub-Category
# Furniture        Bookcases       0.0
#                  Chairs          0.0
#                  Furnishings     0.0
#                  Tables          0.0
# Office Supplies  Appliances      0.0
#                  Art             0.0
#                  Binders         0.0
#                  Envelopes       0.0
#                  Fasteners       0.0
#                  Labels          0.0
#                  Paper           0.0
#                  Storage         0.0
#                  Supplies        0.0
# Technology       Accessories     0.0
#                  Copiers         0.0
#                  Machines        0.0
#                  Phones          0.0
# Name: Profit, dtype: float64

# %%
y3 = data.groupby(['Category','Sub-Category'],as_index=True).Profit.mean()

# %%
y3
# Out:
# Category         Sub-Category
# Furniture        Bookcases       151.313799
#                  Chairs           96.845271
#                  Furnishings      32.919220
#                  Tables          260.352021
# Office Supplies  Appliances      154.726515
#                  Art              20.795995
#                  Binders          28.994784
#                  Envelopes        21.188395
#                  Fasteners        10.178531
#                  Labels            8.654617
#                  Paper            22.540272
#                  Storage          51.603367
#                  Supplies         24.472530
# Technology       Accessories      68.078569
#                  Copiers         180.685070
#                  Machines        145.500404
#                  Phones          121.999809
# Name: Profit, dtype: float64

# %%
#9. for Sales

# %%
z1 = data.groupby(['Category','Sub-Category'],as_index=True).Sales.max()

# %%
z1
# Out:
# Category         Sub-Category
# Furniture        Bookcases        5667.87
#                  Chairs           5759.96
#                  Furnishings      1519.14
#                  Tables           5451.30
# Office Supplies  Appliances       7958.58
#                  Art              1113.02
#                  Binders          9892.74
#                  Envelopes         604.66
#                  Fasteners         271.32
#                  Labels            786.48
#                  Paper             733.95
#                  Storage          2962.68
#                  Supplies         8187.65
# Technology       Accessories      3449.88
#                  Copiers         17499.95
#                  Machines        22638.48
#                  Phones           6998.64
# Name: Sales, dtype: float64

# %%
z2 = data.groupby(['Category','Sub-Category'],as_index=True).Sales.min()

# %%
z2
# Out:
# Category         Sub-Category
# Furniture        Bookcases       35.49
#                  Chairs          13.55
#                  Furnishings      1.89
#                  Tables          24.37
# Office Supplies  Appliances       0.44
#                  Art              1.34
#                  Binders          0.56
#                  Envelopes        1.63
#                  Fasteners        1.24
#                  Labels           1.67
#                  Paper            3.38
#                  Storage          2.80
#                  Supplies         2.92
# Technology       Accessories      0.99
#                  Copiers         35.46
#                  Machines        11.51
#                  Phones           2.97
# Name: Sales, dtype: float64

# %%
z3= data.groupby(['Category','Sub-Category'],as_index=True).Sales.mean()

# %%
z3
# Out:
# Category         Sub-Category
# Furniture        Bookcases       608.283928
#                  Chairs          437.298241
#                  Furnishings     122.116725
#                  Tables          879.259199
# Office Supplies  Appliances      580.100896
#                  Art              76.400843
#                  Binders          75.149705
#                  Envelopes        70.891320
#                  Fasteners        34.407993
#                  Labels           28.200903
#                  Paper            69.240455
#                  Storage         223.175635
#                  Supplies        100.877084
# Technology       Accessories     243.654400
#                  Copiers         679.008776
#                  Machines        524.266703
#                  Phones          508.437489
# Name: Sales, dtype: float64
